# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, ru
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv('./snapit/Pre_NLP.csv')

# %%
df_testis=pd.read_csv('./snapit/test.csv')

# %%
pre_df=pd.read_csv('./snapit/Pre_CountVectorizer(Tr+Test).csv')

# %%
df_test = pre_df[250000:]

# %%
df_test.drop(axis="columns", labels="Unnamed: 0", inplace=True)
# Out:
# /tmp/ipykernel_4236/1956447075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test.drop(axis="columns", labels="Unnamed: 0", inplace=True)

# %%
df_test.shape
# Out:
# (222381, 9)

# %%
df_test.head()
# Out:
#                        PRODUCT_NAME  PRODUCT_CONDITION PRODUCT_BRAND  \
# 250000  f ship 4 totoro washi 1 pen                  1           Tag
# 250001        ucla men bundle short                  1        Adidas
# 250002                  listing lol                  1       Unknown
# 250003   25 pc kawaii sticker flake                  1       Unknown
# 250004     chanel mini lipgloss set                  2        Chanel
#
#         SHIPPING_AVAILABILITY  \
# 250000                      1
# 250001                      1
# 250002                      1
# 250003                      1
# 250004                      1
#
#                                       PRODUCT_DESCRIPTION CATEGORY_1  \
# 250000  listing 4 totoro washi tape limited time offer...   handmade
# 250001        7 item 1 xl 2 2xl 3 2xl 4 xl 5 2xl 6 o 7 38      women
# 250002                                  sunglass necklace     beauty
# 250003        ordered bunch sticker recieve many cute one       kids
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                   PRODUCT_NAME  PRODUCT_CONDITION  \
# 0           0  lipstick queen reserved maiwu                  4
# 1           1       garbage pail kid blu ray                  3
# 2           2              green floam slime                  1
# 3           3          wallet beige monogram                  1
# 4           4  triangle bike body blue light                  3
#
#     PRODUCT_BRAND  SHIPPING_AVAILABILITY  \
# 0  Lipstick Queen                      0
# 1         Unknown                      1
# 2             CHI                      0
# 3         Unknown                      0
# 4         Triangl                      0
#
#                                  PRODUCT_DESCRIPTION  PRODUCT_PRICE  \
# 0  lipstick queen jean queen medieval lipstick us...           20.0
# 1               26plays great tested watched scratch           15.0
# 2  6 oz dragon fruit scented keep reach young chi...            8.0
# ...

# %%
# print(df.iloc[1])

# %%
df.drop(axis="columns", labels="Unnamed: 0", inplace=True)

# %%
df_test.head()
# Out:
#                        PRODUCT_NAME  PRODUCT_CONDITION PRODUCT_BRAND  \
# 250000  f ship 4 totoro washi 1 pen                  1           Tag
# 250001        ucla men bundle short                  1        Adidas
# 250002                  listing lol                  1       Unknown
# 250003   25 pc kawaii sticker flake                  1       Unknown
# 250004     chanel mini lipgloss set                  2        Chanel
#
#         SHIPPING_AVAILABILITY  \
# 250000                      1
# 250001                      1
# 250002                      1
# 250003                      1
# 250004                      1
#
#                                       PRODUCT_DESCRIPTION CATEGORY_1  \
# 250000  listing 4 totoro washi tape limited time offer...   handmade
# 250001        7 item 1 xl 2 2xl 3 2xl 4 xl 5 2xl 6 o 7 38      women
# 250002                                  sunglass necklace     beauty
# 250003        ordered bunch sticker recieve many cute one       kids
# ...

# %%
(df.isna()).sum()
# Out:
# PRODUCT_NAME             0
# PRODUCT_CONDITION        0
# PRODUCT_BRAND            0
# SHIPPING_AVAILABILITY    0
# PRODUCT_DESCRIPTION      0
# PRODUCT_PRICE            0
# CATEGORY_1               0
# CATEGORY_2               0
# CATEGORY_3               0
# dtype: int64

# %%
(df.fillna('Not available',inplace=True))

# %%
(df_test.isna()).sum()
# Out:
# PRODUCT_NAME               0
# PRODUCT_CONDITION          0
# PRODUCT_BRAND              0
# SHIPPING_AVAILABILITY      0
# PRODUCT_DESCRIPTION        0
# CATEGORY_1               911
# CATEGORY_2               911
# CATEGORY_3               911
# PRODUCT_DETAILS            0
# dtype: int64

# %%
df_test['PRODUCT_NAME'].fillna('Not available',inplace=True)
df_test['PRODUCT_DESCRIPTION'].fillna('Not available',inplace=True)
# Out:
# /tmp/ipykernel_4236/2630656929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['PRODUCT_NAME'].fillna('Not available',inplace=True)
# /tmp/ipykernel_4236/2630656929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['PRODUCT_DESCRIPTION'].fillna('Not available',inplace=True)

# %%
# temp=[]
# c=0
# for i in range(df.shape[0]):
#   c=c+1
#   if(c%100000==0):
#     print(c)
#   temp.append(str(df['PRODUCT_NAME'][i])+str(df['PRODUCT_DESCRIPTION'][i]))

# %%
# df['PRODUCT_DETAILS']=temp

# %%
# outliers = df.index[df['PRODUCT_PRICE']>100]

# %%
# outliers

# %%
# df.drop(axis="rows", index=outliers, inplace=True)

# %%
# df['PRODUCT_NAME'][34]

# %%
# temp=[]
# c=0
# for i in range(df.shape[0]):
#   c=c+1
#   if(c%100000==0):
#     print(c)
#   temp.append(str(df['PRODUCT_NAME'][i])+str(df['PRODUCT_DESCRIPTION'][i]))

# %%
# df['PRODUCT_DETAILS']=temp

# %%
df_test.head()

# %%
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()

# df['CATEGORY_1']=le.fit_transform(df['CATEGORY_1'])
# df['CATEGORY_2']=le.fit_transform(df['CATEGORY_2'])
# df['CATEGORY_3']=le.fit_transform(df['CATEGORY_3'])
# df['PRODUCT_BRAND']=le.fit_transform(df['PRODUCT_BRAND'])

# df_test['CATEGORY_1']=le.fit_transform(df_test['CATEGORY_1'])
# df_test['CATEGORY_2']=le.fit_transform(df_test['CATEGORY_2'])
# df_test['CATEGORY_3']=le.fit_transform(df_test['CATEGORY_3'])
# df_test['PRODUCT_BRAND']=le.fit_transform(df_test['PRODUCT_BRAND'])

# %%
# from sklearn import preprocessing
# oh = preprocessing.OneHotEncoder()

# X_cat1=oh.fit_transform(df['CATEGORY_1'])
# X_cat2=oh.fit_transform(df['CATEGORY_2'])
# X_cat3=oh.fit_transform(df['CATEGORY_3'])
# X_brand=oh.fit_transform(df['PRODUCT_BRAND'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
# cv = CountVectorizer(max_features=20000)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tv= TfidfVectorizer(max_features=20000)

# %%
# X_brand.shape

# %%
df_test['CATEGORY_1']=df_test['CATEGORY_1'].fillna('unknown')
df_test['CATEGORY_2']=df_test['CATEGORY_2'].fillna('unknown')
df_test['CATEGORY_3']=df_test['CATEGORY_3'].fillna('unknown')
# Out:
# /tmp/ipykernel_4236/372141119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['CATEGORY_1']=df_test['CATEGORY_1'].fillna('unknown')
# /tmp/ipykernel_4236/372141119.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['CATEGORY_2']=df_test['CATEGORY_2'].fillna('unknown')
# /tmp/ipykernel_4236/372141119.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
cv1 = CountVectorizer()
cv1.fit(df['CATEGORY_1'].values)
cv2 = CountVectorizer()
cv2.fit(df['CATEGORY_2'].values)
cv3 = CountVectorizer()
cv3.fit(df['CATEGORY_3'].values)
cv4 = CountVectorizer()
cv4.fit(df['PRODUCT_BRAND'].values)


X_cat1 = cv1.transform(df['CATEGORY_1'])
X_cat2 = cv2.transform(df['CATEGORY_2'])
X_cat3 = cv3.transform(df['CATEGORY_3'])
X_brand = cv4.transform(df['PRODUCT_BRAND'])


X_cat1_test = cv1.transform(df_test['CATEGORY_1'])
X_cat2_test = cv2.transform(df_test['CATEGORY_2'])
X_cat3_test = cv3.transform(df_test['CATEGORY_3'])
X_brand_test = cv4.transform(df_test['PRODUCT_BRAND'])

# %%
tv1= TfidfVectorizer(max_features=20000)
tv1.fit(df['PRODUCT_DESCRIPTION'].values)
tv2= TfidfVectorizer(max_features=20000)
tv2.fit(df['PRODUCT_NAME'].values)
# Out:
# TfidfVectorizer(max_features=20000)

# %%
X = tv1.transform(df['PRODUCT_DESCRIPTION'])
X_name = tv2.transform(df['PRODUCT_NAME'])

# %%
X.shape
# Out:
# (1254004, 20000)

# %%
type(X)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
X_test = tv1.transform(df_test['PRODUCT_DESCRIPTION'])
X_test_name = tv2.transform(df_test['PRODUCT_NAME'])

# %%
X_test.shape
# Out:
# (222381, 20000)

# %%
# df=pd.concat([df,pd.DataFrame(X.toarray())],axis=1,join='inner')

# %%
# test_df=pd.concat([test_df,pd.DataFrame(X_test.toarray())],axis=1,join='inner')

# %%
df.head()
# Out:
#                     PRODUCT_NAME  PRODUCT_CONDITION   PRODUCT_BRAND  \
# 0  lipstick queen reserved maiwu                  4  Lipstick Queen
# 1       garbage pail kid blu ray                  3         Unknown
# 2              green floam slime                  1             CHI
# 3          wallet beige monogram                  1         Unknown
# 4  triangle bike body blue light                  3         Triangl
#
#    SHIPPING_AVAILABILITY                                PRODUCT_DESCRIPTION  \
# 0                      0  lipstick queen jean queen medieval lipstick us...
# 1                      1               26plays great tested watched scratch
# 2                      0  6 oz dragon fruit scented keep reach young chi...
# 3                      0                        wallet brand new never used
# 4                      0  triangle bike body blue light steady flashing ...
#
#    PRODUCT_PRICE       CATEGORY_1           CATEGORY_2   CATEGORY_3
# ...

# %%
train_y=df['PRODUCT_PRICE']

# %%
df.drop(axis='columns', labels={'PRODUCT_NAME','PRODUCT_DESCRIPTION','PRODUCT_PRICE'},inplace=True)

# %%
df_test.drop(axis='columns', labels={'PRODUCT_NAME','PRODUCT_DESCRIPTION','PRODUCT_DETAILS'},inplace=True)
# Out:
# /tmp/ipykernel_4236/2701848754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test.drop(axis='columns', labels={'PRODUCT_NAME','PRODUCT_DESCRIPTION','PRODUCT_DETAILS'},inplace=True)

# %%
df.head()
# Out:
#    PRODUCT_CONDITION   PRODUCT_BRAND  SHIPPING_AVAILABILITY       CATEGORY_1  \
# 0                  4  Lipstick Queen                      0           beauty
# 1                  3         Unknown                      1      electronics
# 2                  1             CHI                      0             kids
# 3                  1         Unknown                      0            women
# 4                  3         Triangl                      0  sports_outdoors
#
#             CATEGORY_2   CATEGORY_3
# 0               makeup         lips
# 1                media      blu_ray
# 2                 toys  arts_crafts
# 3  women_s_accessories      wallets
# 4             outdoors        other

# %%
df_test.head()
# Out:
#         PRODUCT_CONDITION PRODUCT_BRAND  SHIPPING_AVAILABILITY CATEGORY_1  \
# 250000                  1           Tag                      1   handmade
# 250001                  1        Adidas                      1      women
# 250002                  1       Unknown                      1     beauty
# 250003                  1       Unknown                      1       kids
# 250004                  2        Chanel                      1     beauty
#
#          CATEGORY_2   CATEGORY_3
# 250000  paper_goods   stationery
# 250001        other        other
# 250002       makeup         lips
# 250003         toys  arts_crafts
# 250004       makeup         lips

# %%
# train_x_other = df[['PRODUCT_CONDITION','PRODUCT_BRAND','SHIPPING_AVAILABILITY','CATEGORY_1','CATEGORY_2','CATEGORY_3']].values
train_x_other = df[['PRODUCT_CONDITION','SHIPPING_AVAILABILITY']].values

# %%
# test_x_other = df_test[['PRODUCT_CONDITION','PRODUCT_BRAND','SHIPPING_AVAILABILITY','CATEGORY_1','CATEGORY_2','CATEGORY_3']].values
test_x_other = df_test[['PRODUCT_CONDITION','SHIPPING_AVAILABILITY']].values

# %%
train_x_other.shape
# Out:
# (1254004, 2)

# %%
test_x_other.shape
# Out:
# (222381, 2)

# %%
from scipy import sparse
train_x = sparse.hstack((X,X_name,train_x_other,X_cat1,X_cat2,X_cat3,X_brand))
test_x = sparse.hstack((X_test,X_test_name, test_x_other,X_cat1_test,X_cat2_test,X_cat3_test,X_brand_test))

# %%
train_x.shape
# Out:
# (1254004, 45864)

# %%
test_x.shape
# Out:
# (222381, 45864)

# %%
# from sklearn import linear_model
# reg = linear_model.Lasso(alpha=0.1)

# %%
# from sklearn.ensemble import RandomForestRegressor
# reg= RandomForestRegressor(random_state=0)

# %%
# # check xgboost version
# from xgboost import XGBRegressor
# reg= XGBRegressor()

# %%
# from sklearn.ensemble import GradientBoostingRegressor
# reg = GradientBoostingRegressor(random_state=0)

# %%
# import lightgbm as lgb
# reg = lgb.LGBMRegressor()

# %%
# from sklearn.linear_model import LinearRegression
# reg = LinearRegression()

# %%
from sklearn.svm import LinearSVR
reg = LinearSVR(epsilon=1.5)

# %%
# from sklearn.svm import SVR
# reg = SVR(kernel = 'rbf')

# %%
train_y.shape
# Out:
# (1254004,)

# %%
# train_y = np.log1p(train_y)

# %%
reg.fit(train_x, train_y)
# Out:
# LinearSVR(epsilon=1.5)

# %%
test_x.shape
# Out:
# (222381, 45864)

# %%
pred = reg.predict(test_x)

# %%
print(pred.min())
print(pred.mean())
print(pred.max())
# Out:
# -12.551034830719306
# 21.893063900664153
# 240.71399999480607

# %%
pred[pred<=3]=3
# pred = np.e** pred -1
# (pred<=0).sum()
# pred[pred>160]=2000
# pred[np.logical_and(pred>150,pred<160)]=1000

# %%
pred.max()
# Out:
# 240.71399999480607

# %%
df_testis['PRODUCT_ID']
# Out:
# 0          777341
# 1         1463629
# 2          350669
# 3          310222
# 4          759257
#            ...
# 222376     491588
# 222377    1410603
# 222378     207926
# 222379     241496
# 222380     563849
# Name: PRODUCT_ID, Length: 222381, dtype: int64

# %%
s=df_testis['PRODUCT_ID']
final = s.to_frame(name="PRODUCT_ID")

# %%
final['PRODUCT_PRICE']=pred

# %%
final
# Out:
#         PRODUCT_ID  PRODUCT_PRICE
# 0           777341       4.945236
# 1          1463629      19.988248
# 2           350669      10.620510
# 3           310222       4.914816
# 4           759257      22.484875
# ...            ...            ...
# 222376      491588      30.585064
# 222377     1410603      28.132456
# 222378      207926      14.886978
# 222379      241496      14.714886
# 222380      563849       6.558658
#
# [222381 rows x 2 columns]

# %%
# from sklearn.model_selection import cross_val_score
# score=cross_val_score(reg, train_x, train_y, cv=12,scoring='neg_root_mean_squared_error')
# score

# %%
def rmlse(pred,y):
    return np.sqrt(((np.square(np.log1p(pred)-np.log1p(y))).sum()/np.size(pred)))

# %%
rmlse(reg.predict(train_x),train_y)
# Out:
# /tmp/ipykernel_4236/1827738981.py:2: RuntimeWarning: invalid value encountered in log1p
#   return np.sqrt(((np.square(np.log1p(pred)-np.log1p(y))).sum()/np.size(pred)))
# 0.5058820261914476

# %%
# from sklearn.model_selection import cross_val_score
# score=cross_val_score(reg, train_x, train_y, cv=12,scoring='neg_mean_squared_log_error')
# score

# %%
# from sklearn import metrics

# %%
# print(metrics.get_scorer_names())

# %%
# final.to_csv("./snapit/LSVRE1_5_OH_TF_40000_alagalag.csv",index=False)

# %%
# import pickle
# pickle.dump(reg,open('./snapit/model.pkl','wb'))
# pickle.dump(cv1,open('./snapit/cat1.pkl','wb'))
# pickle.dump(cv2,open('./snapit/cat2.pkl','wb'))
# pickle.dump(cv3,open('./snapit/cat3.pkl','wb'))
# pickle.dump(cv4,open('./snapit/brand.pkl','wb'))
# pickle.dump(tv,open('./snapit/productdetails.pkl','wb'))
